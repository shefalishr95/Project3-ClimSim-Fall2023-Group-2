# %% [markdown]
# ## 1: Set up dependencies

# %%
pip install datasets
# Out:
# ...
#      |████████████████████████████████| 493 kB 31.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 115 kB 154.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 133.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133 kB 157.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 11.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 40.1 MB 77.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 193 kB 122.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 228 kB 158.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 269 kB 148.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 114 kB 153.5 MB/s eta 0:00:01
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.61.2
#     Uninstalling tqdm-4.61.2:
#       Successfully uninstalled tqdm-4.61.2
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset
from datasets import get_dataset_split_names
from datasets import get_dataset_config_names

# %% [markdown]
# ## 2. Load data

# %%
# Check configuration of the dataset
configs = get_dataset_config_names("LEAP/subsampled_low_res")
print(configs)
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# ['default']

# %%
# Check data splits
get_dataset_split_names("LEAP/subsampled_low_res")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# ['train', 'validation']

# %%
# Attempt to load data from a single file to check if it works
dataset = load_dataset("LEAP/subsampled_low_res", data_files={'train': 'train_input.parquet'})
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
#
#
#
#
# ...
#
#
#
#
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 346.18it/s]
#
#
#
#
# Generating train split: 0 examples [00:00, ? examples/s]
#
#
#
# Generating train split: 10000 examples [00:08, 1209.51 examples/s]
#
#
#
# Generating train split: 140000 examples [00:08, 23237.43 examples/s]
#
#
#
# Generating train split: 280000 examples [00:08, 55691.61 examples/s]
#
#
#
# Generating train split: 420000 examples [00:08, 99240.57 examples/s]
#
#
#
# Generating train split: 560000 examples [00:08, 156397.11 examples/s]
#
#
#
# Generating train split: 700000 examples [00:08, 229731.79 examples/s]
#
#
#
# Generating train split: 840000 examples [00:08, 318776.88 examples/s]
#
#
#
# Generating train split: 970000 examples [00:09, 415711.71 examples/s]
#
#
#
# Generating train split: 1160000 examples [00:09, 561965.87 examples/s]
#
#
#
# Generating train split: 1300000 examples [00:09, 676849.24 examples/s]
# ...

# %%
# Load all the required data files
train_input = load_dataset("LEAP/subsampled_low_res", data_files={'train': 'train_input.parquet'})
train_target = load_dataset("LEAP/subsampled_low_res", data_files={'train': 'train_target.parquet'})
val_input = load_dataset("LEAP/subsampled_low_res", data_files={'validation': 'val_input.parquet'})
val_target = load_dataset("LEAP/subsampled_low_res", data_files={'validation': 'val_target.parquet'})
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Repo card metadata block was not found. Setting CardData to empty.
# ...
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 581.73it/s]
# Generating train split: 10091520 examples [00:15, 631415.55 examples/s]
# Repo card metadata block was not found. Setting CardData to empty.
# Repo card metadata block was not found. Setting CardData to empty.
# ...
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 523.05it/s]
# Generating validation split: 1441920 examples [00:03, 462308.03 examples/s]

# %% [markdown]
# ## 3. Check if loading job successful

# %%
# Index and check data
val_target['validation'][0]
# Out:
# {'0': -0.013662081211805344,
#  '1': -0.02804097719490528,
#  '2': -0.021565662696957588,
#  '3': -0.05239439383149147,
#  '4': -0.08133846521377563,
#  '5': -0.11081334948539734,
#  '6': -0.10611506551504135,
#  '7': -0.07643787562847137,
#  '8': -0.049887776374816895,
#  '9': -0.03917437046766281,
#  '10': -0.027251025661826134,
#  '11': -0.01975528709590435,
#  '12': -0.01454482227563858,
#  '13': -0.010380525141954422,
#  '14': -0.005296040326356888,
#  '15': -0.0007867668755352497,
#  '16': 0.0010081222280859947,
#  '17': 0.0010371218668296933,
#  '18': 0.0026053432375192642,
#  '19': 0.0006220536888577044,
#  '20': -0.000980621320195496,
#  '21': -0.004211819730699062,
#  '22': -0.00836136844009161,
#  '23': -0.012373129837214947,
#  '24': -0.017474930733442307,
#  '25': -0.021477028727531433,
#  '26': -0.021938659250736237,
#  '27': -0.022726302966475487,
#  '28': -0.022967858240008354,
#  '29': -0.022556336596608162,
#  '30': -0.02360290288925171,
# ...

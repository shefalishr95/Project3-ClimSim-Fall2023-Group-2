# %% [markdown]
# # Import data_utils

# %%
import os

# Change directory on level up
os.chdir('..')

# %%
# Now, if you are in the directory containing setup.py, you can run:
# !pip install .
# Out:
# Processing d:\fall2023\ads\climsim
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: xarray in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (2023.10.1)
# Requirement already satisfied: numpy in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (1.26.1)
# Requirement already satisfied: pandas in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (2.1.1)
# Requirement already satisfied: matplotlib in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (3.8.0)
# Requirement already satisfied: tensorflow in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: netCDF4 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (1.6.4)
# Requirement already satisfied: h5py in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (3.10.0)
# Requirement already satisfied: tqdm in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from climsim-utils==0.0.1) (4.66.1)
# Collecting scikit-learn (from climsim-utils==0.0.1)
#   Downloading scikit_learn-1.3.2-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from matplotlib->climsim-utils==0.0.1) (6.1.0)
# Requirement already satisfied: cftime in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from netCDF4->climsim-utils==0.0.1) (1.6.3)
# Requirement already satisfied: certifi in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from netCDF4->climsim-utils==0.0.1) (2023.7.22)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from pandas->climsim-utils==0.0.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from pandas->climsim-utils==0.0.1) (2023.3)
# Collecting scipy>=1.5.0 (from scikit-learn->climsim-utils==0.0.1)
#   Downloading scipy-1.11.3-cp39-cp39-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.4 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 796.3 kB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn->climsim-utils==0.0.1)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->climsim-utils==0.0.1)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow->climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (4.24.4)
# Requirement already satisfied: setuptools in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.14.0)
# Requirement already satisfied: colorama in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tqdm->climsim-utils==0.0.1) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->climsim-utils==0.0.1) (3.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (6.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.0.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\clare\anaconda3\envs\myenv3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow->climsim-utils==0.0.1) (3.2.2)
# Downloading scikit_learn-1.3.2-cp39-cp39-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.3 MB 57.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.3 MB 85.5 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 85.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 66.1 MB/s eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------- 302.2/302.2 kB ? eta 0:00:00
# Downloading scipy-1.11.3-cp39-cp39-win_amd64.whl (44.3 MB)
#    ---------------------------------------- 0.0/44.3 MB ? eta -:--:--
#    ---- ----------------------------------- 4.8/44.3 MB 102.2 MB/s eta 0:00:01
#    -------- ------------------------------- 9.5/44.3 MB 101.1 MB/s eta 0:00:01
#    ------------ --------------------------- 14.2/44.3 MB 108.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 19.1/44.3 MB 110.0 MB/s eta 0:00:01
#    --------------------- ------------------ 23.9/44.3 MB 110.0 MB/s eta 0:00:01
#    -------------------------- ------------- 29.0/44.3 MB 108.8 MB/s eta 0:00:01
#    ------------------------------ --------- 33.5/44.3 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.2/44.3 MB 108.8 MB/s eta 0:00:01
#    -------------------------------------- - 42.9/44.3 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.3 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.3 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.3 MB 110.0 MB/s eta 0:00:01
#    ---------------------------------------- 44.3/44.3 MB 43.7 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Building wheels for collected packages: climsim-utils
#   Building wheel for climsim-utils (setup.py): started
#   Building wheel for climsim-utils (setup.py): finished with status 'done'
#   Created wheel for climsim-utils: filename=climsim_utils-0.0.1-py3-none-any.whl size=14564 sha256=03a0e3938ee314cd16d21a079beea367dabf93685210acc25b797babba1ec1ca
#   Stored in directory: C:\Users\Clare\AppData\Local\Temp\pip-ephem-wheel-cache-qn2g8u9_\wheels\69\ff\fb\d091e68acacd863564049a179cec74e3e2daaece7240891d10
# Successfully built climsim-utils
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, climsim-utils
#   Attempting uninstall: climsim-utils
#     Found existing installation: climsim-utils 0.0.1
#     Uninstalling climsim-utils-0.0.1:
#       Successfully uninstalled climsim-utils-0.0.1
# Successfully installed climsim-utils-0.0.1 joblib-1.3.2 scikit-learn-1.3.2 scipy-1.11.3 threadpoolctl-3.2.0

# %%
from climsim_utils.data_utils import *

# %%
print(os.getcwd())
# Out:
# D:\fall2023\ADS\ClimSim

# %% [markdown]
# # Instantiate class

# %%
grid_path = 'demo_notebooks/ClimSim_low-res_grid-info.nc'
norm_path = 'preprocessing/normalizations/'

grid_info = xr.open_dataset(grid_path)
input_mean = xr.open_dataset(norm_path + 'inputs/input_mean.nc')
input_max = xr.open_dataset(norm_path + 'inputs/input_max.nc')
input_min = xr.open_dataset(norm_path + 'inputs/input_min.nc')
output_scale = xr.open_dataset(norm_path + 'outputs/output_scale.nc')

data = data_utils(grid_info = grid_info, 
                  input_mean = input_mean, 
                  input_max = input_max, 
                  input_min = input_min, 
                  output_scale = output_scale)

# set variables to V1 subset
data.set_to_v1_vars()

# %% [markdown]
# # Load training and validation data

# %%
# Change this path to your own
data_path = 'subsampled_low_res/'

train_input_path = data_path + 'train_input.npy'
train_target_path = data_path + 'train_target.npy'
val_input_path = data_path + 'val_input.npy'
val_target_path = data_path + 'val_target.npy'

data.input_train = data.load_npy_file(train_input_path)
data.target_train = data.load_npy_file(train_target_path)
data.input_val = data.load_npy_file(val_input_path)
data.target_val = data.load_npy_file(val_target_path)

# %% [markdown]
# # Custom Model test over here
# ## 1. Random Forest Regresso

# %%
data.input_train.shape
# Out:
# (10091520, 124)

# %%
data.target_train.shape
# Out:
# (10091520, 128)

# %%
data.input_val.shape
# Out:
# (1441920, 124)

# %%
data.target_val.shape
# Out:
# (1441920, 128)

# %%
import numpy as np

# Number of samples for training and validation
num_samples_train = 384000
num_samples_val = 38400

# Generate random indices without replacement for training data
indices_train = np.random.choice(data.input_train.shape[0], num_samples_train, replace=False)

# Subset the training data using these indices
input_train_subset = data.input_train[indices_train]
target_train_subset = data.target_train[indices_train]

# Generate random indices without replacement for validation data
indices_val = np.random.choice(data.input_val.shape[0], num_samples_val, replace=False)

# Subset the validation data using these indices
input_val_subset = data.input_val[indices_val]
target_val_subset = data.target_val[indices_val]

# %%
data.input_train = input_train_subset
data.target_train = target_train_subset
data.input_val = input_val_subset
data.target_val = target_val_subset

# %%
from sklearn.ensemble import RandomForestRegressor
# Initialize the model
rf_regressor = RandomForestRegressor(n_estimators=50, n_jobs=-1, random_state=42)  # Adjust hyperparameters as needed

# Train the model
rf_regressor.fit(data.input_train, data.target_train)
# Out:
# RandomForestRegressor(n_estimators=50, n_jobs=-1, random_state=42)

# %%
from datetime import datetime

# Print the current time, 4:14 start
print(datetime.now())
# Out:
# 2023-10-29 17:12:46.833849

# %%
# Predict using the Random Forest regressor
rf_pred_val = rf_regressor.predict(data.input_val)
print(rf_pred_val.shape)
# Out:
# (38400, 128)

# %%
from datetime import datetime

# Print the current time, 4:14 start
print(datetime.now())
# Out:
# 2023-10-29 18:03:49.051019

# %%
# Use the muliti-linear regression model for comparison
X = data.input_train
bias_vector = np.ones((X.shape[0], 1))
X = np.concatenate((X, bias_vector), axis=1)
mlr_weights = np.linalg.inv(X.transpose()@X)@X.transpose()@data.target_train
X_val = data.input_val
bias_vector_val = np.ones((X_val.shape[0], 1))
X_val = np.concatenate((X_val, bias_vector_val), axis=1)
mlr_pred_val = X_val@mlr_weights
print(mlr_pred_val.shape)
# Out:
# (38400, 128)

# %%
# Add the RF predictions to the existing list and dictionary
# data.model_names = ['rf'] # specify the name of your model here
# preds = [rf_pred_val] # specify your custom predictions here
# data.preds_val = dict(zip(data.model_names, preds))

data.model_names = ['rf', 'mlr'] # add names of your models here
preds = [rf_pred_val, mlr_pred_val] # add your custom predictions here
data.preds_val = dict(zip(data.model_names, preds))

# %%
data.set_pressure_grid(data_split = 'val')

# %%
data.reweight_target(data_split = 'val')
data.reweight_preds(data_split = 'val')
# Out:
# (38400, 128)
# (38400, 128)
# (38400, 128)

# %%
data.metrics_names = ['MAE', 'RMSE', 'R2']
data.create_metrics_df(data_split = 'val')
# Out:
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:706: RuntimeWarning: divide by zero encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:706: RuntimeWarning: invalid value encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:706: RuntimeWarning: divide by zero encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:706: RuntimeWarning: invalid value encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time

# %%
# set plotting settings
# %config InlineBackend.figure_format = 'retina'
letters = string.ascii_lowercase

# create custom dictionary for plotting
dict_var = data.metrics_var_val
plot_df_byvar = {}
for metric in data.metrics_names:
    plot_df_byvar[metric] = pd.DataFrame([dict_var[model][metric] for model in data.model_names],
                                               index=data.model_names)
    plot_df_byvar[metric] = plot_df_byvar[metric].rename(columns = data.var_short_names).transpose()

# plot figure
fig, axes = plt.subplots(nrows  = len(data.metrics_names), sharex = True)
for i in range(len(data.metrics_names)):
    plot_df_byvar[data.metrics_names[i]].plot.bar(
        legend = False,
        ax = axes[i])
    if data.metrics_names[i] != 'R2':
        axes[i].set_ylabel('$W/m^2$')
    else:
        axes[i].set_ylim(0,1)

    axes[i].set_title(f'({letters[i]}) {data.metrics_names[i]}')
axes[i].set_xlabel('Output variable')
axes[i].set_xticklabels(plot_df_byvar[data.metrics_names[i]].index, \
    rotation=0, ha='center')

axes[0].legend(columnspacing = .9, 
               labelspacing = .3,
               handleheight = .07,
               handlelength = 1.5,
               handletextpad = .2,
               borderpad = .2,
               ncol = 3,
               loc = 'upper right')
fig.set_size_inches(7,8)
fig.tight_layout()

# %%
# This is the result obtained after training around 384000 data and validate with around 38400 data
# %config InlineBackend.figure_format = 'retina'
letters = string.ascii_lowercase

# create custom dictionary for plotting
dict_var = data.metrics_var_val
plot_df_byvar = {}
for metric in data.metrics_names:
    plot_df_byvar[metric] = pd.DataFrame([dict_var[model][metric] for model in data.model_names],
                                               index=data.model_names)
    plot_df_byvar[metric] = plot_df_byvar[metric].rename(columns = data.var_short_names).transpose()

# plot figure
fig, axes = plt.subplots(nrows  = len(data.metrics_names), sharex = True)
for i in range(len(data.metrics_names)):
    plot_df_byvar[data.metrics_names[i]].plot.bar(
        legend = False,
        ax = axes[i])
    if data.metrics_names[i] != 'R2':
        axes[i].set_ylabel('$W/m^2$')
    else:
        axes[i].set_ylim(0,1)

    axes[i].set_title(f'({letters[i]}) {data.metrics_names[i]}')
axes[i].set_xlabel('Output variable')
axes[i].set_xticklabels(plot_df_byvar[data.metrics_names[i]].index, \
    rotation=0, ha='center')

axes[0].legend(columnspacing = .9, 
               labelspacing = .3,
               handleheight = .07,
               handlelength = 1.5,
               handletextpad = .2,
               borderpad = .2,
               ncol = 3,
               loc = 'upper right')
fig.set_size_inches(7,8)
fig.tight_layout()

# %%
# from datetime import datetime

# # Print the current time
# print(datetime.now())

# %% [markdown]
# # Train models

# %% [markdown]
# ### Train constant prediction model
#
# $\hat{y} = E[y_{train}]$

# %%
const_model = data.target_train.mean(axis = 0)

# %% [markdown]
# ### Train multiple linear regression model
#
# $\beta = {(X_{train}^TX_{train})}^{-1}X_{train}^Ty_{train}$
#
# $\hat{y} = X_{input}^T \beta$
#
# where $X_{train}$ and $X_{input}$ correspond to the training data and the input data you would like to inference on, respectively. $X_{train}$ and $X_{input}$ both have a column of ones concatenated to the feature space for the bias.

# %% [markdown]
# ##### adding bias unit

# %%
X = data.input_train
bias_vector = np.ones((X.shape[0], 1))
X = np.concatenate((X, bias_vector), axis=1)

# %% [markdown]
# ##### create model

# %%
mlr_weights = np.linalg.inv(X.transpose()@X)@X.transpose()@data.target_train

# %% [markdown]
# ### Train your models here

# %%
### 
# train your model here
###

# %% [markdown]
# # Evaluate on validation data

# %% [markdown]
# ### Set pressure grid

# %%
data.set_pressure_grid(data_split = 'val')

# %% [markdown]
# ### Load predictions

# %%
# Constant Prediction
const_pred_val = np.repeat(const_model[np.newaxis, :], data.target_val.shape[0], axis = 0)
print(const_pred_val.shape)

# Multiple Linear Regression
X_val = data.input_val
bias_vector_val = np.ones((X_val.shape[0], 1))
X_val = np.concatenate((X_val, bias_vector_val), axis=1)
mlr_pred_val = X_val@mlr_weights
print(mlr_pred_val.shape)

# Load your prediction here

# Load predictions into data_utils object
data.model_names = ['const', 'mlr'] # add names of your models here
preds = [const_pred_val, mlr_pred_val] # add your custom predictions here
data.preds_val = dict(zip(data.model_names, preds))
# Out:
# (1441920, 128)
# (1441920, 128)

# %% [markdown]
# ### Weight predictions and target
#
# 1. Undo output scaling
#
# 2.  Weight vertical levels by dp/g
#
# 3. Weight horizontal area of each grid cell by a[x]/mean(a[x])
#
# 4. Convert units to a common energy unit

# %%
data.reweight_target(data_split = 'val')
data.reweight_preds(data_split = 'val')

# %% [markdown]
# ### Set and calculate metrics

# %%
data.metrics_names = ['MAE', 'RMSE', 'R2', 'bias']
data.create_metrics_df(data_split = 'val')
# Out:
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: divide by zero encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: invalid value encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: divide by zero encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: invalid value encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time

# %% [markdown]
# ### Create plots

# %%
# set plotting settings
# %config InlineBackend.figure_format = 'retina'
letters = string.ascii_lowercase

# create custom dictionary for plotting
dict_var = data.metrics_var_val
plot_df_byvar = {}
for metric in data.metrics_names:
    plot_df_byvar[metric] = pd.DataFrame([dict_var[model][metric] for model in data.model_names],
                                               index=data.model_names)
    plot_df_byvar[metric] = plot_df_byvar[metric].rename(columns = data.var_short_names).transpose()

# plot figure
fig, axes = plt.subplots(nrows  = len(data.metrics_names), sharex = True)
for i in range(len(data.metrics_names)):
    plot_df_byvar[data.metrics_names[i]].plot.bar(
        legend = False,
        ax = axes[i])
    if data.metrics_names[i] != 'R2':
        axes[i].set_ylabel('$W/m^2$')
    else:
        axes[i].set_ylim(0,1)

    axes[i].set_title(f'({letters[i]}) {data.metrics_names[i]}')
axes[i].set_xlabel('Output variable')
axes[i].set_xticklabels(plot_df_byvar[data.metrics_names[i]].index, \
    rotation=0, ha='center')

axes[0].legend(columnspacing = .9, 
               labelspacing = .3,
               handleheight = .07,
               handlelength = 1.5,
               handletextpad = .2,
               borderpad = .2,
               ncol = 3,
               loc = 'upper right')
fig.set_size_inches(7,8)
fig.tight_layout()

# %% [markdown]
# If you trained models with different hyperparameters, use the ones that performed the best on validation data for evaluation on scoring data.

# %% [markdown]
# ## Evaluate on scoring data
#
# #### Do this at the VERY END (when you have finished tuned the hyperparameters for your  model and are seeking a final evaluation)

# %% [markdown]
# ### Load scoring data

# %%
scoring_input_path = "subsampled_low_res/scoring_input.npy"
scoring_target_path = "subsampled_low_res/scoring_target.npy"

# path to target input
data.input_scoring = np.load(scoring_input_path)

# path to target output
data.target_scoring = np.load(scoring_target_path)

# %% [markdown]
# ### Set pressure grid

# %%
data.set_pressure_grid(data_split = 'scoring')

# %% [markdown]
# ### Load predictions

# %%
# constant prediction
const_pred_scoring = np.repeat(const_model[np.newaxis, :], data.target_scoring.shape[0], axis = 0)
print(const_pred_scoring.shape)

# multiple linear regression
X_scoring = data.input_scoring
bias_vector_scoring = np.ones((X_scoring.shape[0], 1))
X_scoring = np.concatenate((X_scoring, bias_vector_scoring), axis=1)
mlr_pred_scoring = X_scoring@mlr_weights
print(mlr_pred_scoring.shape)

# Your model prediction here

# Load predictions into object
data.model_names = ['const', 'mlr'] # model name here
preds = [const_pred_scoring, mlr_pred_scoring] # add prediction here
data.preds_scoring = dict(zip(data.model_names, preds))
# Out:
# (1681920, 128)
# (1681920, 128)

# %% [markdown]
# ### Weight predictions and target
#
# 1. Undo output scaling
#
# 2.  Weight vertical levels by dp/g
#
# 3. Weight horizontal area of each grid cell by a[x]/mean(a[x])
#
# 4. Convert units to a common energy unit

# %%
# weight predictions and target
data.reweight_target(data_split = 'scoring')
data.reweight_preds(data_split = 'scoring')

# set and calculate metrics
data.metrics_names = ['MAE', 'RMSE', 'R2', 'bias']
data.create_metrics_df(data_split = 'scoring')
# Out:
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: divide by zero encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: invalid value encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: divide by zero encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time
# D:\fall2023\ADS\ClimSim\climsim_utils\data_utils.py:705: RuntimeWarning: invalid value encountered in divide
#   r_squared = 1 - sq_diff.sum(axis = 0)/tss_time.sum(axis = 0) # sum over time

# %% [markdown]
# ### Create plots

# %%
# set plotting settings
# %config InlineBackend.figure_format = 'retina'
letters = string.ascii_lowercase

# create custom dictionary for plotting
dict_var = data.metrics_var_scoring
plot_df_byvar = {}
for metric in data.metrics_names:
    plot_df_byvar[metric] = pd.DataFrame([dict_var[model][metric] for model in data.model_names],
                                               index=data.model_names)
    plot_df_byvar[metric] = plot_df_byvar[metric].rename(columns = data.var_short_names).transpose()

# plot figure
fig, axes = plt.subplots(nrows  = len(data.metrics_names), sharex = True)
for i in range(len(data.metrics_names)):
    plot_df_byvar[data.metrics_names[i]].plot.bar(
        legend = False,
        ax = axes[i])
    if data.metrics_names[i] != 'R2':
        axes[i].set_ylabel('$W/m^2$')
    else:
        axes[i].set_ylim(0,1)

    axes[i].set_title(f'({letters[i]}) {data.metrics_names[i]}')
axes[i].set_xlabel('Output variable')
axes[i].set_xticklabels(plot_df_byvar[data.metrics_names[i]].index, \
    rotation=0, ha='center')

axes[0].legend(columnspacing = .9, 
               labelspacing = .3,
               handleheight = .07,
               handlelength = 1.5,
               handletextpad = .2,
               borderpad = .2,
               ncol = 3,
               loc = 'upper right')
fig.set_size_inches(7,8)
fig.tight_layout()
